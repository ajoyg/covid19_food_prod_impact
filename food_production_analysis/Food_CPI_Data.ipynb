# %% [markdown]
# ## Staging the CPI data from 2018 to 2022 for food items

# %%
import csv
import pandas as pd

# %%
#Read the CSV file and prepare to add it to a dataframe
csvpath="Resources/BLS_CPI_FOOD.csv"
#open the BLS_CPI_FOOD.csv file
with open(csvpath, encoding='utf8') as CPI_FOOD_DATA:
    food_price_reader = csv.reader(CPI_FOOD_DATA, delimiter=',')
    series_id = None
    series_title = None
    area = None
    item = None
    price_data = []
    for row in food_price_reader:
        # If the row starts with "Series Id:", "Series Title:", "Area:", or "Item:",
        # extract the corresponding information and continue to the next row
        if row:
            if row[0].startswith('Series Id:'):
                series_id = row[0].split(':')[1].strip()
            elif row[0].startswith('Series Title:'):
                row[0] = row[0].split(':')[1].strip()
                series_title = ''.join(row)
            elif row[0].startswith('Area:'):
                area = row[0].split(':')[1].strip()
            elif row[0].startswith('Item:'):
                row[0] = row[0].split(':')[1].strip()
                item=''.join(row)
            elif row[0].isdigit():
                # If the first column is a digit, assume it's a year and extract the prices
                prices = [p if p != 'No Data Available for selected year(s)' else None for p in row[0:]]
                prices.insert(0,item)
                price_data.append(prices)
#Add the dataset to a datafrane
item_price_data_df = pd.DataFrame(price_data, columns=['Item','Year','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
item_price_data_df.set_index("Item", inplace=True)

# %%
item_price_data_df
# Out:
#                                             Year    Jan    Feb    Mar    Apr  \
# Item
# Flour white all purpose per lb. (453.6 gm)  2018  0.471  0.470  0.468  0.472
# Flour white all purpose per lb. (453.6 gm)  2019  0.439  0.443  0.445  0.434
# Flour white all purpose per lb. (453.6 gm)  2020  0.438  0.438  0.442
# Flour white all purpose per lb. (453.6 gm)  2021  0.446  0.440  0.436  0.437
# Flour white all purpose per lb. (453.6 gm)  2022  0.424  0.428  0.448  0.455
# ...                                          ...    ...    ...    ...    ...
# Lettuce romaine per lb. (453.6 gm)          2018  2.127  2.072  2.064  2.129
# Lettuce romaine per lb. (453.6 gm)          2019  2.177  2.300  2.356  2.300
# Lettuce romaine per lb. (453.6 gm)          2020  2.160  2.029
# Lettuce romaine per lb. (453.6 gm)          2021
# Lettuce romaine per lb. (453.6 gm)          2022  3.178  3.182  3.154  3.187
#
#                                               May    Jun    Jul    Aug    Sep  \
# Item
# Flour white all purpose per lb. (453.6 gm)  0.469  0.469  0.468  0.464  0.467
# Flour white all purpose per lb. (453.6 gm)  0.454  0.448  0.454  0.450  0.449
# Flour white all purpose per lb. (453.6 gm)  0.461  0.468  0.461  0.459  0.451
# Flour white all purpose per lb. (453.6 gm)  0.439  0.356  0.368  0.371  0.382
# Flour white all purpose per lb. (453.6 gm)  0.456  0.498  0.533  0.549  0.556
# ...                                           ...    ...    ...    ...    ...
# Lettuce romaine per lb. (453.6 gm)          2.039  1.937  2.056  2.043  2.058
# Lettuce romaine per lb. (453.6 gm)          2.190  2.115  2.207  2.162  2.059
# Lettuce romaine per lb. (453.6 gm)
# Lettuce romaine per lb. (453.6 gm)
# Lettuce romaine per lb. (453.6 gm)          2.993  2.973  2.927  2.841  3.003
#
#                                               Oct    Nov    Dec
# Item
# Flour white all purpose per lb. (453.6 gm)  0.453  0.433  0.437
# Flour white all purpose per lb. (453.6 gm)  0.432  0.417  0.429
# Flour white all purpose per lb. (453.6 gm)  0.452  0.445  0.450
# Flour white all purpose per lb. (453.6 gm)  0.396  0.386  0.388
# Flour white all purpose per lb. (453.6 gm)  0.534  0.524  0.522
# ...                                           ...    ...    ...
# Lettuce romaine per lb. (453.6 gm)          2.132  2.170  2.352
# Lettuce romaine per lb. (453.6 gm)          2.203  2.214  2.176
# Lettuce romaine per lb. (453.6 gm)
# Lettuce romaine per lb. (453.6 gm)                        3.269
# Lettuce romaine per lb. (453.6 gm)          3.138  3.487  3.568
#
# [238 rows x 13 columns]

# %%
#Save the item price CPI data into a csv in the staging folder
item_price_data_df.to_csv("staging/food_cpi.csv")

# %%
#Retrieve the item price data from the csv
item_price_data_df = pd.read_csv("staging/food_cpi.csv").set_index("Item")
item_price_data_df.head(20)
# Out:
#                                                    Year    Jan    Feb    Mar  \
# Item
# Flour white all purpose per lb. (453.6 gm)         2018  0.471  0.470  0.468
# Flour white all purpose per lb. (453.6 gm)         2019  0.439  0.443  0.445
# Flour white all purpose per lb. (453.6 gm)         2020  0.438  0.438  0.442
# Flour white all purpose per lb. (453.6 gm)         2021  0.446  0.440  0.436
# Flour white all purpose per lb. (453.6 gm)         2022  0.424  0.428  0.448
# Rice white long grain uncooked per lb. (453.6 gm)  2018  0.682  0.691  0.682
# Rice white long grain uncooked per lb. (453.6 gm)  2019  0.730  0.762  0.757
# Rice white long grain uncooked per lb. (453.6 gm)  2020  0.716  0.734  0.733
# Rice white long grain uncooked per lb. (453.6 gm)  2021  0.794  0.779  0.772
# Rice white long grain uncooked per lb. (453.6 gm)  2022  0.832  0.830  0.871
# Spaghetti and macaroni per lb. (453.6 gm)          2018  1.218  1.176  1.187
# Spaghetti and macaroni per lb. (453.6 gm)          2019  1.217  1.206  1.237
# Spaghetti and macaroni per lb. (453.6 gm)          2020  1.225  1.235  1.238
# Spaghetti and macaroni per lb. (453.6 gm)          2021  1.314  1.324  1.341
# Spaghetti and macaroni per lb. (453.6 gm)          2022  1.116  1.148  1.182
# Bread white pan per lb. (453.6 gm)                 2018  1.281  1.265  1.309
# Bread white pan per lb. (453.6 gm)                 2019  1.274  1.282  1.261
# Bread white pan per lb. (453.6 gm)                 2020  1.351  1.375  1.374
# Bread white pan per lb. (453.6 gm)                 2021  1.546  1.537  1.526
# Bread white pan per lb. (453.6 gm)                 2022  1.555  1.578  1.607
#
#                                                      Apr    May    Jun    Jul  \
# Item
# Flour white all purpose per lb. (453.6 gm)         0.472  0.469  0.469  0.468
# Flour white all purpose per lb. (453.6 gm)         0.434  0.454  0.448  0.454
# Flour white all purpose per lb. (453.6 gm)                0.461  0.468  0.461
# Flour white all purpose per lb. (453.6 gm)         0.437  0.439  0.356  0.368
# Flour white all purpose per lb. (453.6 gm)         0.455  0.456  0.498  0.533
# Rice white long grain uncooked per lb. (453.6 gm)  0.685  0.698  0.689  0.690
# Rice white long grain uncooked per lb. (453.6 gm)  0.767  0.761  0.801  0.798
# Rice white long grain uncooked per lb. (453.6 gm)         0.748  0.749  0.772
# Rice white long grain uncooked per lb. (453.6 gm)  0.785  0.801  0.778  0.782
# Rice white long grain uncooked per lb. (453.6 gm)  0.900  0.909  0.924  0.929
# Spaghetti and macaroni per lb. (453.6 gm)          1.176  1.143  1.201  1.204
# Spaghetti and macaroni per lb. (453.6 gm)          1.223  1.197  1.192  1.198
# Spaghetti and macaroni per lb. (453.6 gm)          1.265  1.260  1.280  1.295
# Spaghetti and macaroni per lb. (453.6 gm)          1.251  1.336  1.073  1.094
# Spaghetti and macaroni per lb. (453.6 gm)          1.217  1.291  1.316  1.349
# Bread white pan per lb. (453.6 gm)                 1.281  1.293  1.279  1.293
# Bread white pan per lb. (453.6 gm)                 1.285  1.289  1.280  1.281
# Bread white pan per lb. (453.6 gm)                 1.406  1.412  1.474  1.485
# Bread white pan per lb. (453.6 gm)                 1.510  1.511  1.510  1.491
# Bread white pan per lb. (453.6 gm)                 1.612  1.606  1.691  1.715
#
#                                                      Aug    Sep    Oct    Nov  \
# Item
# Flour white all purpose per lb. (453.6 gm)         0.464  0.467  0.453  0.433
# Flour white all purpose per lb. (453.6 gm)         0.450  0.449  0.432  0.417
# Flour white all purpose per lb. (453.6 gm)         0.459  0.451  0.452  0.445
# Flour white all purpose per lb. (453.6 gm)         0.371  0.382  0.396  0.386
# Flour white all purpose per lb. (453.6 gm)         0.549  0.556  0.534  0.524
# Rice white long grain uncooked per lb. (453.6 gm)  0.705  0.693  0.685  0.711
# Rice white long grain uncooked per lb. (453.6 gm)  0.793  0.797  0.773  0.721
# Rice white long grain uncooked per lb. (453.6 gm)  0.769  0.777  0.766  0.791
# Rice white long grain uncooked per lb. (453.6 gm)  0.784  0.798  0.788  0.844
# Rice white long grain uncooked per lb. (453.6 gm)  0.925  0.939  0.963  0.963
# Spaghetti and macaroni per lb. (453.6 gm)          1.227  1.200  1.138  1.196
# Spaghetti and macaroni per lb. (453.6 gm)          1.215  1.184  1.178  1.231
# Spaghetti and macaroni per lb. (453.6 gm)          1.303  1.256  1.220  1.262
# Spaghetti and macaroni per lb. (453.6 gm)          1.089  1.077  1.067  1.093
# Spaghetti and macaroni per lb. (453.6 gm)          1.368  1.357  1.349  1.428
# Bread white pan per lb. (453.6 gm)                 1.302  1.288  1.277  1.274
# Bread white pan per lb. (453.6 gm)                 1.275  1.296  1.325  1.361
# Bread white pan per lb. (453.6 gm)                 1.495  1.492  1.503  1.515
# Bread white pan per lb. (453.6 gm)                 1.467  1.580  1.526  1.547
# Bread white pan per lb. (453.6 gm)                 1.756  1.749  1.814  1.847
#
#                                                      Dec
# Item
# Flour white all purpose per lb. (453.6 gm)         0.437
# Flour white all purpose per lb. (453.6 gm)         0.429
# Flour white all purpose per lb. (453.6 gm)         0.450
# Flour white all purpose per lb. (453.6 gm)         0.388
# Flour white all purpose per lb. (453.6 gm)         0.522
# Rice white long grain uncooked per lb. (453.6 gm)  0.712
# Rice white long grain uncooked per lb. (453.6 gm)  0.714
# Rice white long grain uncooked per lb. (453.6 gm)  0.789
# Rice white long grain uncooked per lb. (453.6 gm)  0.820
# Rice white long grain uncooked per lb. (453.6 gm)  0.971
# Spaghetti and macaroni per lb. (453.6 gm)          1.161
# Spaghetti and macaroni per lb. (453.6 gm)          1.189
# Spaghetti and macaroni per lb. (453.6 gm)          1.313
# Spaghetti and macaroni per lb. (453.6 gm)          1.092
# Spaghetti and macaroni per lb. (453.6 gm)          1.434
# Bread white pan per lb. (453.6 gm)                 1.290
# Bread white pan per lb. (453.6 gm)                 1.363
# Bread white pan per lb. (453.6 gm)                 1.538
# Bread white pan per lb. (453.6 gm)                 1.532
# Bread white pan per lb. (453.6 gm)                 1.873
