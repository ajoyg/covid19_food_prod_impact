# %%
#Loading and cleaning of USDA_Commidity data for year 2016-2022

# %%
import glob
import pandas as pd

# %%
# Read all .csv files to concatenate
all_files = glob.glob('Data files_usda/*.csv')

usda_list = []

for filename in all_files:
    usda_list_df = pd.read_csv(filename, index_col=None, header=0)
    usda_list.append(usda_list_df)

usda_df = pd.concat(usda_list, axis=0, ignore_index=True)

# Write the concatenated dataframe to a new CSV file
usda_df.to_csv("../staging/usda_concatenated.csv", index=False)

usda_df.head()
# Out:
#    WasdeNumber    ReportDate  \
# 0          549  January 2016
# 1          549  January 2016
# 2          549  January 2016
# 3          549  January 2016
# 4          549  January 2016
#
#                                          ReportTitle         Attribute  \
# 0  Mexico Sugar Supply and Use and High Fructose ...  Beginning Stocks
# 1  Mexico Sugar Supply and Use and High Fructose ...          Domestic
# 2  Mexico Sugar Supply and Use and High Fructose ...     Ending Stocks
# 3  Mexico Sugar Supply and Use and High Fructose ...           Exports
# 4  Mexico Sugar Supply and Use and High Fructose ...           Imports
#
#   ReliabilityProjection Commodity  Region MarketYear ProjEstFlag  \
# 0                   NaN     Sugar  Mexico    2014/15        Est.
# 1                   NaN     Sugar  Mexico    2014/15        Est.
# 2                   NaN     Sugar  Mexico    2014/15        Est.
# 3                   NaN     Sugar  Mexico    2014/15        Est.
# 4                   NaN     Sugar  Mexico    2014/15        Est.
#
#   AnnualQuarterFlag   Value                             Unit ReleaseDate  \
# 0            Annual   831.0  1000 Metric Tons, Actual Weight  2016-01-12
# 1            Annual  4691.0  1000 Metric Tons, Actual Weight  2016-01-12
# 2            Annual   811.0  1000 Metric Tons, Actual Weight  2016-01-12
# 3            Annual  1442.0  1000 Metric Tons, Actual Weight  2016-01-12
# 4            Annual   128.0  1000 Metric Tons, Actual Weight  2016-01-12
#
#         ReleaseTime  ForecastYear  ForecastMonth
# 0  12:00:00.0000000          2016              1
# 1  12:00:00.0000000          2016              1
# 2  12:00:00.0000000          2016              1
# 3  12:00:00.0000000          2016              1
# 4  12:00:00.0000000          2016              1
